# %%
import text_preprocessing as tp

# %%
x = 'I am Currently learning Machine learning and Deep learning Algorithms and many more things.'

# %%
tp.get_wordcloud(x)

# %%
tp.sentiment_analysis(x)
# Out:
# 'pos'

# %%
tp.convert_to_base(x)
# Out:
# 'I am Currently learn Machine learning and Deep learn Algorithms and many more thing.'

# %%
tp.get_noun_phrase(x)
# Out:
# WordList(['currently', 'machine', 'deep', 'algorithms'])

# %%
tp.char_count(x)
# Out:
# 78

# %%
tp.avg_word_len(x)
# Out:
# 5.571428571428571

# %%
tp.stop_words_count(x)
# Out:
# 6
